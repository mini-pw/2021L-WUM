# %% [markdown]
# # Projekt 1
# ### P. Fijałkowski, M. Krzyziński, T. Nocoń
#
# ## Eksploracja danych

# %% [markdown]
# #### Wczytanie pakietów

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Wstępne informacje i wczytanie danych
# W projekcie będziemy pracować nad zbiorem danym *Census income* zawierającym informacje pochodzące ze spisu ludności Amerykanów. Celem zadania będzie klasyfikacja, czy zarobki danej osoby przekroczą próg 50 tys. $ rocznie.
#
# Informacje dotyczące zbioru, jak i same dane możemy znaleźć na [stronie](https://www.apispreadsheets.com/datasets/106).

# %%
df = pd.read_csv("https://lovespreadsheet-tutorials.s3.amazonaws.com/APIDatasets/census_income_dataset.csv")
attr = pd.read_csv("attributes_census_income.csv")

# %%
df
# Out:
#        age         workclass    fnlwgt  education  education_num  \
# 0       39         State-gov   77516.0  Bachelors             13
# 1       50  Self-emp-not-inc   83311.0  Bachelors             13
# 2       38           Private  215646.0    HS-grad              9
# 3       53           Private  234721.0       11th              7
# 4       28           Private  338409.0  Bachelors             13
# ...    ...               ...       ...        ...            ...
# 48837   39           Private  215419.0  Bachelors             13
# 48838   64                 ?  321403.0    HS-grad              9
# 48839   38           Private  374983.0  Bachelors             13
# 48840   44           Private   83891.0  Bachelors             13
# 48841   35      Self-emp-inc  182148.0  Bachelors             13
#
#            marital_status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# 2                Divorced  Handlers-cleaners   Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners         Husband
# 4      Married-civ-spouse     Prof-specialty            Wife
# ...                   ...                ...             ...
# 48837            Divorced     Prof-specialty   Not-in-family
# 48838             Widowed                  ?  Other-relative
# 48839  Married-civ-spouse     Prof-specialty         Husband
# 48840            Divorced       Adm-clerical       Own-child
# 48841  Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 0                   White    Male        2174.0           0.0            40.0
# 1                   White    Male           0.0           0.0            13.0
# 2                   White    Male           0.0           0.0            40.0
# 3                   Black    Male           0.0           0.0            40.0
# 4                   Black  Female           0.0           0.0            40.0
# ...                   ...     ...           ...           ...             ...
# 48837               White  Female           0.0           0.0            36.0
# 48838               Black    Male           0.0           0.0            40.0
# 48839               White    Male           0.0           0.0            50.0
# 48840  Asian-Pac-Islander    Male        5455.0           0.0            40.0
# 48841               White    Male           0.0           0.0            60.0
#
#       native_country income_level
# 0      United-States        <=50K
# 1      United-States        <=50K
# 2      United-States        <=50K
# 3      United-States        <=50K
# 4               Cuba        <=50K
# ...              ...          ...
# 48837  United-States        <=50K
# 48838  United-States        <=50K
# 48839  United-States        <=50K
# 48840  United-States        <=50K
# 48841  United-States         >50K
#
# [48842 rows x 15 columns]

# %%
with pd.option_context('display.max_colwidth', 400):
    display(attr)
# Out:
#               name     type  \
# 0              age  integer
# 1        workclass   string
# 2           fnlwgt    float
# 3        education   string
# 4    education_num  integer
# 5   marital_status   string
# 6       occupation   string
# 7     relationship   string
# 8             race   string
# 9              sex   string
# 10    capital_gain    float
# 11    capital_loss    float
# 12  hours_per_week    float
# 13  native_country   string
# 14    income_level   string
#
#                                                                                                                                                                                                                                                                                                                                                                                                         description
# 0                                                                                                                                                                                                                                                                                                                                                                                                 age of individual
# 1                                                                                                                                                                                                                                                                                                     Values: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked
# 2                                                                                                                                                                                                                                                                                     Final sampling weight. Inverse of sampling fraction adjusted for non-response and over or under sampling of particular groups
# 3                                                                                                                                                                                                                                                     Values: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool
# 4                                                                                                                                                                                                                                                                                                                                                                                                               NaN
# 5                                                                                                                                                                                                                                                                                                 Values: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse
# 6                                                                                                                                                                                  Values: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces
# 7                                                                                                                                                                                                                                                                                                                                        Values: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried
# 8                                                                                                                                                                                                                                                                                                                                               Values: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black
# 9                                                                                                                                                                                                                                                                                                                                                                                              Values: Female, Male
# 10                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 11                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 12                                                                                                                                                                                                                                                                                                                                                                                           working hours per week
# 13  Values: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru...
# 14                                                                                                                                                                                                                                                                                                                    Predictor class if individual earns greater or less than $50000 per year. Values: <=50K, >50K

# %% [markdown]
# Większość zmiennych ma samotłumaczące się nazwy, natomiast dość kłopotliwa wydaje się `fnlwgt` - jest to final sampling weight. Poszczególne rekordy mają przypisaną odpowiednią wagę, aby odzwierciedlać populację. Jest to więc statystyczny parametr, który nie będzie przydatny w tworzeniu modelu predykcji, ani w dalszej analizie, w związku z czym usuniemy tę kolumnę.

# %%
df.drop("fnlwgt", axis=1, inplace=True)

# %%
df.shape
# Out:
# (48842, 14)

# %% [markdown]
# Już na wstępie możemy zauważyć, że mamy 15 kolumn, spośród których jedna będzie targetem - `income_level` zawierająca informacje odnośnie przekroczenia lub nieprzekroczenia progu zarobkowego 50 tys. dolarów.
#
# Ponadto nawet wyświetlając ramkę widzimy w niektórych kolumnach znaki zapytania `?`. Również na stronie, z której pobieramy zbiór znajdziemy informacje, że brakujące wartości zostały wypełnione znakami zapytania `?` bądź wartością `-100000`. Będziemy musieli się uporać zatem z problemem brakujących danych. Ale sprawdźmy dla zasady, czy może niektóre wartości w ramce rzeczywiście pozostały `NULL`ami...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   education       48842 non-null  object
#  3   education_num   48842 non-null  int64
#  4   marital_status  48842 non-null  object
#  5   occupation      48842 non-null  object
#  6   relationship    48842 non-null  object
#  7   race            48842 non-null  object
#  8   sex             48842 non-null  object
#  9   capital_gain    48842 non-null  float64
#  10  capital_loss    48842 non-null  float64
#  11  hours_per_week  48842 non-null  float64
#  12  native_country  48842 non-null  object
#  13  income_level    48842 non-null  object
# dtypes: float64(3), int64(2), object(9)
# memory usage: 5.2+ MB

# %% [markdown]
# Okazuje się, że nie. Zatem rzeczywiście wszystkie ewentualne brakujące wartości zostały zastąpione w określony wyżej sposób.
#
# Przy okazji widzimy również, jakiego typu są nasze kolumny.
#
# Sprawdźmy teraz, jak dużo mamy braków w rzeczywistości (tych zatuszowanych).

# %%
print(f'{df[(df == "?").any(axis = 1)].shape[0]} wierszy, w których występuje brak danych zastąpiony `?`')
# Out:
# 3620 wierszy, w których występuje brak danych zastąpiony `?`

# %%
print(f'{df[(df == -100000).any(axis = 1)].shape[0]} wierszy, w których występuje brak danych zastąpiony `-100000`')
# Out:
# 0 wierszy, w których występuje brak danych zastąpiony `-100000`

# %% [markdown]
# Mamy 3620 wierszy z brakiem danych. W poleceniu projektowym znajduje się informacja, że zalecane jest ograniczenie liczby rekordów, w związku z czym są one kandydatem do usunięcia ze zbioru przed modelowaniem. Na czas analizy zastąpimy te wartości NaNami.

# %%
df[df == "?"] = np.nan

# %%
df.isna().sum()
# Out:
# age                  0
# workclass         2799
# education            0
# education_num        0
# marital_status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     857
# income_level         0
# dtype: int64

# %% [markdown]
# Widzimy, w których kolumnach występują braki danych. Przy czym możemy zbadać, że dla rekordów, gdzie mamy brak danych dotyczący klasy roboczej nie ma również informacji o zawodzie, co wydaje się naturalne.

# %%
df[df["workclass"].isna() & df["occupation"].isna()]
# Out:
#        age workclass     education  education_num         marital_status  \
# 27      54       NaN  Some-college             10     Married-civ-spouse
# 61      32       NaN       7th-8th              4  Married-spouse-absent
# 69      25       NaN  Some-college             10          Never-married
# 77      67       NaN          10th              6     Married-civ-spouse
# 106     17       NaN          10th              6          Never-married
# ...    ...       ...           ...            ...                    ...
# 48682   61       NaN  Some-college             10     Married-civ-spouse
# 48769   21       NaN  Some-college             10          Never-married
# 48800   73       NaN       HS-grad              9     Married-civ-spouse
# 48812   81       NaN     Assoc-voc             11     Married-civ-spouse
# 48838   64       NaN       HS-grad              9                Widowed
#
#       occupation    relationship                race     sex  capital_gain  \
# 27           NaN         Husband  Asian-Pac-Islander    Male           0.0
# 61           NaN   Not-in-family               White    Male           0.0
# 69           NaN       Own-child               White    Male           0.0
# 77           NaN         Husband               White    Male           0.0
# 106          NaN       Own-child               White  Female       34095.0
# ...          ...             ...                 ...     ...           ...
# 48682        NaN         Husband               White    Male           0.0
# 48769        NaN       Own-child               White  Female           0.0
# 48800        NaN         Husband               White    Male           0.0
# 48812        NaN         Husband               White    Male        2936.0
# 48838        NaN  Other-relative               Black    Male           0.0
#
#        capital_loss  hours_per_week native_country income_level
# 27              0.0            60.0          South         >50K
# 61              0.0            40.0            NaN        <=50K
# 69              0.0            40.0  United-States        <=50K
# 77              0.0             2.0  United-States        <=50K
# 106             0.0            32.0  United-States        <=50K
# ...             ...             ...            ...          ...
# 48682           0.0            14.0  United-States        <=50K
# 48769           0.0            30.0  United-States        <=50K
# 48800           0.0            25.0         Canada        <=50K
# 48812           0.0            20.0  United-States        <=50K
# 48838           0.0            40.0  United-States        <=50K
#
# [2799 rows x 14 columns]

# %% [markdown]
# Zanim przejdziemy do wizualizacji, sprawdźmy parametry statystyczne naszych zmiennych numerycznych.

# %%
df.describe()
# Out:
#                 age  education_num  capital_gain  capital_loss  hours_per_week
# count  48842.000000   48842.000000  48842.000000  48842.000000    48842.000000
# mean      38.643585      10.078089   1079.067626     87.502314       40.422382
# std       13.710510       2.570973   7452.019058    403.004552       12.391444
# min       17.000000       1.000000      0.000000      0.000000        1.000000
# 25%       28.000000       9.000000      0.000000      0.000000       40.000000
# 50%       37.000000      10.000000      0.000000      0.000000       40.000000
# 75%       48.000000      12.000000      0.000000      0.000000       45.000000
# max       90.000000      16.000000  99999.000000   4356.000000       99.000000

# %% [markdown]
# Już w tym momencie widzimy, że zmienne `capital_gain` i	`capital_loss` mogą okazać się problematyczne, ze względu na bardzo odstające obserwacje. Widzimy też, że minimalny wiek uwzględnionych w ramce osób to 17 lat, co zgadza się z opisem zbioru na stronie.
#
# Widzimy również zakres wartości zmiennej `education_num`. Okazuje się, że liczby te odpowiadają poszczególnym poziomom edukacji wyrażonym słownie w kolumnie `education`, w związku z tym w modelu należy wykorzystać tylko jedną zmienną (numeryczna daje nam w tym przypadku pożądaną hierarchizację poszczególnych szczebli edukacji).

# %%
# kolumny education_num i education oznaczają to samo -
# dla każdej liczby w education_num jest tylko jedna wartość w education 
for i in range(1, max(df["education_num"])+1):
    print(i, df[df["education_num"] == i]["education"].unique())
# Out:
# 1 ['Preschool']
# 2 ['1st-4th']
# 3 ['5th-6th']
# 4 ['7th-8th']
# 5 ['9th']
# 6 ['10th']
# 7 ['11th']
# 8 ['12th']
# 9 ['HS-grad']
# 10 ['Some-college']
# 11 ['Assoc-voc']
# 12 ['Assoc-acdm']
# 13 ['Bachelors']
# 14 ['Masters']
# 15 ['Prof-school']
# 16 ['Doctorate']

# %%
# stworzymy więc odpowiednią listę, która posłuży do skategoryzowania zmiennej i wprowadzenia porządku
education_list = []
for i, name in df.groupby(["education_num", "education"]).groups.keys():
    education_list += [name]

df["education"] = pd.Categorical(df["education"], 
                                categories=education_list, ordered=True)

# %% [markdown]
# #### Histogramy

# %% [markdown]
# Mamy tylko 4 zmienne typowo numeryczne, które można przedstawić na histogramach.

# %%
sns.displot(data = df, x = "age", binwidth = 1, aspect = 1.5, kde = True)
plt.show()

# %% [markdown]
# Widzimy, że rozkład wieku przypomina normalny. Oczywiście jest ucięty z lewej strony, gdyż dane są tylko dla osób powyżej 16 roku życia. Co ciekawe wydaje się, że wszystkim osobom w wieku 90+ został przypisany wiek 90 lat (dane zostały obcięte).

# %%
sns.displot(data = df, x = "hours_per_week", binwidth = 5, aspect = 1.5, kde = True)
plt.show()

# %% [markdown]
# Widzimy, że znaczna większość osób pracuje 40 godzin tygodniowo, ale są i takie, dla których dane podają około 100 godzin pracy.

# %%
df[["capital_gain", "capital_loss"]].hist(bins = 40, figsize = (10, 6))
plt.show()

# %% [markdown]
# W przypadku zmiennych capital gain i loss widzimy, że są one zerowe dla większości rekordów i nie pomoże tu również ich zlogarytmowanie (być może warto będzie wprowadzić kolumnę, która będzie ich różnicą). Warto jednak sprawdzić, jak wyglądają ich rozkłady z pominięciem tych zerowych wartości.

# %%
sns.displot(data = df[df["capital_gain"]>0], x = "capital_gain", aspect = 1.5, kde = True)
plt.show()

# %% [markdown]
# Okazuje się chociażby, że także wartości w kolumnie capital_gain zostały przycięte do 100000.

# %%
sns.displot(data = df[df["capital_loss"]>0], x = "capital_loss", aspect = 1.5, kde = True)
plt.show()

# %% [markdown]
# #### Korelacje

# %% [markdown]
# Na czas sprawdzania korelacji zmapujemy informację o przekroczeniu progu zarobkowego na liczby.

# %%
df[">50K"] = df.loc[:,"income_level"].map({'<=50K': 0, '>50K': 1})
df["income_level"] = pd.Categorical(df["income_level"], categories=[">50K", "<=50K"], ordered=True)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(method = "spearman"), annot=True, vmin=-1, vmax=1, cmap="BrBG")
plt.show()

# %% [markdown]
# Widzimy korelacje naszej zmiennej wyjaśnianej z każdą pozostałą ujętą w macierzy,  w szczególności z education_num.

# %% [markdown]
# #### Dalsza eksploracja danych

# %% [markdown]
# Zanim zaczniemy myśleć o bardziej skomplikowanych zależnościach, spójrzmy, ile mamy rekordów zaklasyfikowanych do poszczególnych grup.

# %%
plt.figure(figsize = (7, 5))
ax = sns.countplot(data = df, x = "income_level", label="count")
for p in ax.patches:
        ax.annotate('{}'.format(p.get_height()), (p.get_x()+0.3, p.get_height()+250))
plt.title("Number of people in income level groups", fontsize=14)
plt.xlabel("Income level", fontsize=14)
plt.ylabel("Number of people", fontsize=14)
plt.show()

# %% [markdown]
# ***
#
#
# Teraz możemy zwrócić uwagę, jak różne zmienne (charakterystyki) wpływają na liczbę osób w obu grupach. Zaczniemy od zmiennych numerycznych. Violinploty wyrysowujemy tak, by szerokość była zgodna z rzeczywistą liczbą obserwacji.

# %%
plt.figure(figsize = (10, 8))
sns.violinplot(data=df, y="income_level", x="age", scale = "count")
plt.title("Income level groups vs age", fontsize=14)
plt.xlabel("Age", fontsize=14)
plt.ylabel("Income level", fontsize=14)
plt.show()

# %% [markdown]
# Widzimy, że to starsi osiągają większe dochody, a młodzi, w szczególności do 25 lat, zarabiają przeciętnie mniej.

# %%
plt.figure(figsize = (10, 8))
sns.violinplot(data=df, y="income_level", x="hours_per_week", scale = "count")
plt.title("Income level groups vs weekly working hours", fontsize=14)
plt.xlabel("Weekly working hours", fontsize=14)
plt.ylabel("Income level", fontsize=14)
plt.show()

# %% [markdown]
# Widzimy, że w większości to Ci pracujący dłużej mogą osiągać częściej większe przychody (zarabiający więcej stanowią około 40% grupy osób, która pracuje ponad 40 godzin).

# %%
df[df["hours_per_week"] > 40][">50K"].mean()
# Out:
# 0.40008361204013376

# %% [markdown]
# ***
#
#
#
# Teraz przejdziemy do analizy związku wysokości dochodów z innymi zmiennymi.

# %%
df.groupby('education')["income_level"].value_counts(normalize=True).unstack('income_level').plot.bar(stacked=True, figsize = (16, 8))
plt.title("Income level groups vs education_level", fontsize=14)
plt.xticks(rotation = 45)
plt.xlabel("Education level", fontsize=14)
plt.ylabel("Share of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# Widać, że poziom edukacji wpływa na wysokość przychodów - im wyższy, tym większa szansa na wysokie zarobki.
# ***

# %%
workclasses_plot_data = df.groupby('workclass')["income_level"].value_counts(normalize=True).unstack('income_level').sort_values(by = ">50K", ascending = False)
workclasses_plot_data.plot.bar(stacked=True, figsize = (12, 8), sort_columns = True)
plt.xticks(rotation = 45)
plt.title("Income level groups vs work classes", fontsize=14)
plt.xlabel("Work class", fontsize=14)
plt.ylabel("Share of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# Widać, że osoby na samozatrudnieniu, prowadzące własną działalność najczęściej zarabiają ponad 50 tys. rocznie. Natomiast wartym uwagi jest fakt, że w sektorze prywatnym zatrudnienie stanowią oni mniejszy procent niż w pozostałych, publicznych klasach. Należy też mieć na uwadze, że większość danych dotyczy osób pracujących w sektorze prywatnym.

# %%
plt.figure(figsize = (12, 8))
sns.countplot(data = df, x = "workclass", order = workclasses_plot_data.index, color = "steelblue")
plt.title("Number of people in work classes", fontsize=14)
plt.xlabel("Work class", fontsize=14)
plt.ylabel("Number of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# ***

# %%
countries_plot_data = df.groupby('native_country')["income_level"].value_counts(normalize=True).unstack('income_level').sort_values(by = ">50K", ascending = False)
countries_plot_data.plot.barh(stacked=True, figsize = (16, 12))
plt.title("Income level groups vs native country", fontsize=14)
plt.ylabel("Native country", fontsize=14)
plt.xlabel("Share of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# Zauważalny jest fakt, że państwa, z których emigranci rzadziej zarabiają powyżej 50 tys. to w większości grupa państw uznawanych za biedniejsze, rozwijające się. Gdybyśmy chcieli, by nasz model działał ogólnie, również dla osób narodowości innej niż te, o których dane mamy, moglibyśmy poszukać zależności ze współczynnikami rozwoju gospodarczego państw i dopasować odpowiednie kategorie, zgrupować część państw. Byłaby to również dobra taktyka ze względu na to, że danych dotyczących krajów innych niż Stany Zjednoczone i Meksyk jest bardzo mało, co widać poniżej.

# %%
plt.figure(figsize = (16, 12))
sns.countplot(data = df, y = "native_country", order = list(countries_plot_data.index)[::-1], color = "steelblue")
plt.title("Number of people from different countries", fontsize=14)
plt.ylabel("Native country", fontsize=14)
plt.xlabel("Number of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# ***

# %%
races_plot_data = df.groupby('race')["income_level"].value_counts(normalize=True).unstack('income_level').sort_values(by = ">50K", ascending = False)
races_plot_data.plot.bar(stacked=True, figsize = (12, 8), sort_columns = True)
plt.xticks(rotation = 0)
plt.title("Income level groups vs ethnic groups", fontsize=14)
plt.xlabel("Ethnic groups", fontsize=14)
plt.ylabel("Share of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# Niestety widać też znaczące różnice w kwestii zarobków w zależności od pochodzenia etnicznego. Natomiast poniżej widzimy, że znaczną część rekordów stanowią osoby przypisane do "rasy białej", w związku z czym warto rozważyć zgrupowanie kategorii (Asian-Pac-Islander i White w jednej kategorii, a pozostałe w drugiej).

# %%
plt.figure(figsize = (12, 8))
sns.countplot(data = df, x = "race", order = races_plot_data.index, color = "steelblue")
plt.title("Number of people in ethnic groups", fontsize=14)
plt.xlabel("Ethnic groups", fontsize=14)
plt.ylabel("Number of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# ***

# %%
marital_status_plot_data  = df.groupby('marital_status')["income_level"].value_counts(normalize=True).unstack('income_level').sort_values(by = ">50K", ascending = False)
marital_status_plot_data.plot.bar(stacked=True, figsize = (12, 8), sort_columns = True)
plt.xticks(rotation = 0)
plt.title("Income level groups vs marital status", fontsize=14)
plt.xlabel("Marital status", fontsize=14)
plt.ylabel("Share of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# Największą szansę na duże zarobki mają teoretycznie osoby w związku małżeńskim, których małżonek nie jest nieobecny. Natomiast liczność kategorii Married-AF-spouse jest tak mała, że również można rozważyć jej złączenie z Married-civ-spouse.

# %%
plt.figure(figsize = (12, 8))
sns.countplot(data = df, x = "marital_status", order = marital_status_plot_data.index, color = "steelblue")
plt.title("Number of people by marital status", fontsize=14)
plt.xlabel("Marital status", fontsize=14)
plt.ylabel("Number of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# Podobne informacje, co status cywilny znajdziemy w kolumnie relationship (większość rekordów to wife i husband, a więc pokrywa się z married w kolumnie marital_status), w związku z czym należy również rozważyć, czy w modelu należy używać obu tych kolumn, czy może wybrać jedną.

# %%
relationship_plot_data  = df.groupby('relationship')["income_level"].value_counts(normalize=True).unstack('income_level').sort_values(by = ">50K", ascending = False)
relationship_plot_data.plot.bar(stacked=True, figsize = (12, 8), sort_columns = True)
plt.xticks(rotation = 0)
plt.title("Income level groups vs relationships", fontsize=14)
plt.xlabel("Relationship", fontsize=14)
plt.ylabel("Share of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# ***

# %%
sex_plot_data = df.groupby('sex')["income_level"].value_counts(normalize=True).unstack('income_level').sort_values(by = ">50K", ascending = False)
sex_plot_data.plot.bar(stacked=True, figsize = (8, 6), sort_columns = True)
plt.xticks(rotation = 0)
plt.title("Income level groups vs sex", fontsize=14)
plt.xlabel("Sex", fontsize=14)
plt.ylabel("Share of people in a given group", fontsize=14)
plt.show()

# %% [markdown]
# Okazuje się, że odsetek mężczyzn zarabiających powyżej 50 tys. jest ok. 3 razy większy niż analogiczny odsetek kobiet. Pokazuje to jak dużym problem w USA był (i wciąż jest) gender pay gap.

# %%
sex_plot_data
# Out:
# income_level      >50K     <=50K
# sex
# Male          0.303767  0.696233
# Female        0.109251  0.890749

# %% [markdown]
# ### Podsumowanie i wnioski

# %% [markdown]
# - Dzięki eksploracji danych zapoznaliśmy się bliżej ze zbiorem, z którym będziemy pracować. Wiemy, co wydaje się mieć wpływ na roczne przychody.
# - Udało się także odkryć kilka kwestii wartych uwagi przy tworzeniu modelu predykcyjnego.
# - Wiemy, której kolumny należy się pozbyć, gdyż nie jest związana ze zmienną wyjaśnianą (cecha nieistotna) - `fnlwgt`.
# - Zlokalizowaliśmy również kolumny, które są reduntantne - `education` i `education_num`, w modelowaniu prawdopodobnie wykorzystamy jedynie `education_num`.
# - Rozważyć należy również odrzucenie kolumn `capital_gain` i `capital_loss`.
# - Mamy również informacje, jakie transformacje wykonać (np. złączenia kategorii), co warto sprawdzić i wypróbować na kolejnym etapie projektu.
